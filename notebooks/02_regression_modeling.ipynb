# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor

import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam 
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
from keras.layers import LSTM
from sklearn.model_selection import KFold, cross_val_score, train_test_split

import pickle
# Out:
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# # Load Data

# %%
model_df = pd.read_csv('../data/model_df.csv')

# %% [markdown]
# # Train Test Split

# %%
def tts(data):
    data = data.drop(['sales','date'],axis=1)
    train, test = data[0:-12].values, data[-12:].values
    
    return train, test

train, test = tts(model_df)

# %%
train.shape
# Out:
# (35, 13)

# %%
test.shape
# Out:
# (12, 13)

# %%
def scale_data(train_set, test_set):
    #apply Min Max Scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train_set)
    
    # reshape training set
    train_set = train_set.reshape(train_set.shape[0], train_set.shape[1])
    train_set_scaled = scaler.transform(train_set)
    
    # reshape test set
    test_set = test_set.reshape(test_set.shape[0], test_set.shape[1])
    test_set_scaled = scaler.transform(test_set)
    
    X_train, y_train = train_set_scaled[:, 1:], train_set_scaled[:, 0:1].ravel()
    X_test, y_test = test_set_scaled[:, 1:], test_set_scaled[:, 0:1].ravel()
    
    return X_train, y_train, X_test, y_test, scaler

X_train, y_train, X_test, y_test, scaler_object = scale_data(train, test)

# %%
y_train.shape
# Out:
# (35,)

# %% [markdown]
# # Modeling Functions

# %%
def undo_scaling(y_pred, x_test, scaler_obj, lstm=False):  
    #reshape y_pred
    y_pred = y_pred.reshape(y_pred.shape[0], 1, 1)
    
    if not lstm:
        x_test = x_test.reshape(x_test.shape[0], 1, x_test.shape[1])
    
    #rebuild test set for inverse transform
    pred_test_set = []
    for index in range(0,len(y_pred)):
        pred_test_set.append(np.concatenate([y_pred[index],x_test[index]],axis=1))
        
    #reshape pred_test_set
    pred_test_set = np.array(pred_test_set)
    pred_test_set = pred_test_set.reshape(pred_test_set.shape[0], pred_test_set.shape[2])
    
    #inverse transform
    pred_test_set_inverted = scaler_obj.inverse_transform(pred_test_set)
    
    return pred_test_set_inverted

# %%
def load_original_df():
    #load in original dataframe without scaling applied
    original_df = pd.read_csv('../data/train.csv')
    original_df.date = original_df.date.apply(lambda x: str(x)[:-3])
    original_df = original_df.groupby('date')['sales'].sum().reset_index()
    original_df.date = pd.to_datetime(original_df.date)
    return original_df

# %%
def predict_df(unscaled_predictions, original_df):
    #create dataframe that shows the predicted sales
    result_list = []
    sales_dates = list(original_df[-13:].date)
    act_sales = list(original_df[-13:].sales)
    
    for index in range(0,len(unscaled_predictions)):
        result_dict = {}
        result_dict['pred_value'] = int(unscaled_predictions[index][0] + act_sales[index])
        result_dict['date'] = sales_dates[index+1]
        result_list.append(result_dict)
        
    df_result = pd.DataFrame(result_list)
    
    return df_result

# %%
model_scores = {}

def get_scores(unscaled_df, original_df, model_name):
    rmse = np.sqrt(mean_squared_error(original_df.sales[-12:], unscaled_df.pred_value[-12:]))
    mae = mean_absolute_error(original_df.sales[-12:], unscaled_df.pred_value[-12:])
    r2 = r2_score(original_df.sales[-12:], unscaled_df.pred_value[-12:])
    model_scores[model_name] = [rmse, mae, r2]

    print(f"RMSE: {rmse}")
    print(f"MAE: {mae}")
    print(f"R2 Score: {r2}")

# %%
def plot_results(results, original_df, model_name):

    fig, ax = plt.subplots(figsize=(15,5))
    sns.lineplot(original_df.date, original_df.sales, data=original_df, ax=ax, 
                 label='Original', color='mediumblue')
    sns.lineplot(results.date, results.pred_value, data=results, ax=ax, 
                 label='Predicted', color='Red')
    
    ax.set(xlabel = "Date",
           ylabel = "Sales",
           title = f"{model_name} Sales Forecasting Prediction")
    
    ax.legend()
    
    sns.despine()
    
    plt.savefig(f'../model_output/{model_name}_forecast.png')

# %%
def run_model(train_data, test_data, model, model_name):
    
    X_train, y_train, X_test, y_test, scaler_object = scale_data(train_data, test_data)
    
    mod = model
    mod.fit(X_train, y_train)
    predictions = mod.predict(X_test)
    
    # Undo scaling to compare predictions against original data
    original_df = load_original_df()
    unscaled = undo_scaling(predictions, X_test, scaler_object)
    unscaled_df = predict_df(unscaled, original_df)
      
    get_scores(unscaled_df, original_df, model_name)
    
    plot_results(unscaled_df, original_df, model_name)

# %% [markdown]
# # Linear Regression

# %%
run_model(train, test, LinearRegression(), 'LinearRegression')
# Out:
# RMSE: 16221.040790693221
# MAE: 12433.0
# R2 Score: 0.9907155879704752
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Random Forest Regressor

# %%
run_model(train, test, RandomForestRegressor(n_estimators=100, max_depth=20), 
          'RandomForest')
# Out:
# RMSE: 19100.74592347988
# MAE: 16510.166666666668
# R2 Score: 0.9871264706306796
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # XGBoost

# %%
run_model(train, test, XGBRegressor( n_estimators=100, 
                                    learning_rate=0.2, 
                                    objective='reg:squarederror'), 'XGBoost')
# Out:
# RMSE: 15701.003359658262
# MAE: 13342.666666666666
# R2 Score: 0.9913013514225064
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # LSTM

# %%
def lstm_model(train_data, test_data):
    
    X_train, y_train, X_test, y_test, scaler_object = scale_data(train_data, test_data)
    
    X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
   
    model = Sequential()
    model.add(LSTM(4, batch_input_shape=(1, X_train.shape[1], X_train.shape[2]), 
                   stateful=True))
    model.add(Dense(1))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(X_train, y_train, epochs=200, batch_size=1, verbose=1, 
              shuffle=False)
    predictions = model.predict(X_test,batch_size=1)
    
    original_df = load_original_df()
    unscaled = undo_scaling(predictions, X_test, scaler_object, lstm=True)
    unscaled_df = predict_df(unscaled, original_df)
    
    get_scores(unscaled_df, original_df, 'LSTM')
    
    plot_results(unscaled_df, original_df, 'LSTM')

# %%
lstm_model(train, test)
# Out:
# Epoch 1/200
# 35/35 [==============================] - 3s 2ms/step - loss: 0.3072
# Epoch 2/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3009
# Epoch 3/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2978
# Epoch 4/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2957
# Epoch 5/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2935
# Epoch 6/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2902
# Epoch 7/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2843
# Epoch 8/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2743
# Epoch 9/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2605
# Epoch 10/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2441
# Epoch 11/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2265
# Epoch 12/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2085
# Epoch 13/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1907
# Epoch 14/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1734
# Epoch 15/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1569
# Epoch 16/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1413
# Epoch 17/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1268
# Epoch 18/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1135
# Epoch 19/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1014
# Epoch 20/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0906
# Epoch 21/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0808
# Epoch 22/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0721
# Epoch 23/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0642
# Epoch 24/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0572
# Epoch 25/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0508
# Epoch 26/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0452
# Epoch 27/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0401
# Epoch 28/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0356
# Epoch 29/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0316
# Epoch 30/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0281
# Epoch 31/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 32/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0224
# Epoch 33/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0201
# Epoch 34/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0181
# Epoch 35/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0164
# Epoch 36/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0149
# Epoch 37/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0137
# Epoch 38/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0126
# Epoch 39/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0116
# Epoch 40/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0108
# Epoch 41/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0101
# Epoch 42/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0095
# Epoch 43/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0089
# Epoch 44/200
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0084
# Epoch 45/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0080
# Epoch 46/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0076
# Epoch 47/200
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 48/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 49/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0067
# Epoch 50/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0065
# Epoch 51/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 52/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 53/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0058
# Epoch 54/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0057
# Epoch 55/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0055
# Epoch 56/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 57/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0052
# Epoch 58/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 59/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 60/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0049
# Epoch 61/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 62/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0047
# Epoch 63/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 64/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 65/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 66/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0044
# Epoch 67/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 68/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0043
# Epoch 69/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 70/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 71/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0041
# Epoch 72/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 73/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0040
# Epoch 74/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 75/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0039
# Epoch 76/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 77/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 78/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 79/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 80/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0037
# Epoch 81/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 82/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 83/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 84/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 85/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 86/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 87/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 88/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 89/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 90/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 91/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 92/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 93/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 94/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 95/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 96/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 97/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 98/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 99/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 100/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 101/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 102/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 103/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 104/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 105/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 106/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 107/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 108/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 109/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 110/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 111/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 112/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 113/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 114/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 115/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 116/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 117/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 118/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 119/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 120/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 121/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 122/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 123/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 124/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 125/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 126/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 127/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 128/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 129/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 130/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 131/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 132/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 133/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 134/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 135/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 136/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 137/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 138/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 139/200
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0026
# Epoch 140/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 141/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 142/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 143/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 144/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 145/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 146/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 147/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 148/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 149/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 150/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 151/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 152/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 153/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 154/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 155/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0025
# Epoch 156/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 157/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 158/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 159/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0025
# Epoch 160/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 161/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 162/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 163/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 164/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 165/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 166/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 167/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 168/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 169/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 170/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0024
# Epoch 171/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 172/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 173/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 174/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 175/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 176/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 177/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 178/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 179/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 180/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 181/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 182/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0023
# Epoch 183/200
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 184/200
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 185/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 186/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 187/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 188/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 189/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 190/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 191/200
# 35/35 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 192/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 193/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 194/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 195/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 196/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 197/200
# 35/35 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 198/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 199/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 200/200
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0021
# 12/12 [==============================] - 0s 1ms/step
# RMSE: 16359.349831722124
# MAE: 13306.583333333334
# R2 Score: 0.9905565855154684
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pickle.dump(model_scores, open( "model_scores.p", "wb" ) )
