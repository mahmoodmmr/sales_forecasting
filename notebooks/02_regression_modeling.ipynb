# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor

import keras
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam 
from keras.callbacks import EarlyStopping
from keras.utils import np_utils
from keras.layers import LSTM
from sklearn.model_selection import KFold, cross_val_score, train_test_split

import pickle

# %% [markdown]
# # Load Data

# %%
model_df = pd.read_csv('../data/model_df.csv')

# %% [markdown]
# # Train Test Split

# %%
def tts(data):
    data = data.drop(['sales','date'],axis=1)
    train, test = data[0:-12].values, data[-12:].values
    
    return train, test

train, test = tts(model_df)

# %%
train.shape
# Out:
# (66, 13)

# %%
test.shape
# Out:
# (12, 13)

# %%
def scale_data(train_set, test_set):
    #apply Min Max Scaler
    scaler = MinMaxScaler(feature_range=(-1, 1))
    scaler = scaler.fit(train_set)
    
    # reshape training set
    train_set = train_set.reshape(train_set.shape[0], train_set.shape[1])
    train_set_scaled = scaler.transform(train_set)
    
    # reshape test set
    test_set = test_set.reshape(test_set.shape[0], test_set.shape[1])
    test_set_scaled = scaler.transform(test_set)
    
    X_train, y_train = train_set_scaled[:, 1:], train_set_scaled[:, 0:1].ravel()
    X_test, y_test = test_set_scaled[:, 1:], test_set_scaled[:, 0:1].ravel()
    
    return X_train, y_train, X_test, y_test, scaler

X_train, y_train, X_test, y_test, scaler_object = scale_data(train, test)

# %%
y_train.shape
# Out:
# (66,)

# %% [markdown]
# # Modeling Functions

# %%
def undo_scaling(y_pred, x_test, scaler_obj, lstm=False):  
    #reshape y_pred
    y_pred = y_pred.reshape(y_pred.shape[0], 1, 1)
    
    if not lstm:
        x_test = x_test.reshape(x_test.shape[0], 1, x_test.shape[1])
    
    #rebuild test set for inverse transform
    pred_test_set = []
    for index in range(0,len(y_pred)):
        pred_test_set.append(np.concatenate([y_pred[index],x_test[index]],axis=1))
        
    #reshape pred_test_set
    pred_test_set = np.array(pred_test_set)
    pred_test_set = pred_test_set.reshape(pred_test_set.shape[0], pred_test_set.shape[2])
    
    #inverse transform
    pred_test_set_inverted = scaler_obj.inverse_transform(pred_test_set)
    
    return pred_test_set_inverted

# %%
def load_original_df():
    #load in original dataframe without scaling applied
    original_df = pd.read_csv('../data/trainWallmart.csv')
    original_df.date = original_df.date.apply(lambda x: str(x)[:-3])
    original_df = original_df.groupby('date')['sales'].sum().reset_index()
    original_df.date = pd.to_datetime(original_df.date)
    return original_df

# %%
def predict_df(unscaled_predictions, original_df):
    #create dataframe that shows the predicted sales
    result_list = []
    sales_dates = list(original_df[-13:].date)
    act_sales = list(original_df[-13:].sales)
    
    for index in range(0,len(unscaled_predictions)):
        result_dict = {}
        result_dict['pred_value'] = int(unscaled_predictions[index][0] + act_sales[index])
        result_dict['date'] = sales_dates[index+1]
        result_list.append(result_dict)
        
    df_result = pd.DataFrame(result_list)
    
    return df_result

# %%
model_scores = {}

def get_scores(unscaled_df, original_df, model_name):
    rmse = np.sqrt(mean_squared_error(original_df.sales[-12:], unscaled_df.pred_value[-12:]))
    mae = mean_absolute_error(original_df.sales[-12:], unscaled_df.pred_value[-12:])
    r2 = r2_score(original_df.sales[-12:], unscaled_df.pred_value[-12:])
    model_scores[model_name] = [rmse, mae, r2]

    print(f"RMSE: {rmse}")
    print(f"MAE: {mae}")
    print(f"R2 Score: {r2}")

# %%
def plot_results(results, original_df, model_name):

    fig, ax = plt.subplots(figsize=(15,5))
    sns.lineplot(original_df.date, original_df.sales, data=original_df, ax=ax, 
                 label='Original', color='mediumblue')
    sns.lineplot(results.date, results.pred_value, data=results, ax=ax, 
                 label='Predicted', color='Red')
    
    ax.set(xlabel = "Date",
           ylabel = "Sales",
           title = f"{model_name} Sales Forecasting Prediction")
    
    ax.legend()
    
    sns.despine()
    
    plt.savefig(f'../model_output/{model_name}_forecast.png')

# %%
def run_model(train_data, test_data, model, model_name):
    
    X_train, y_train, X_test, y_test, scaler_object = scale_data(train_data, test_data)
    
    mod = model
    mod.fit(X_train, y_train)
    predictions = mod.predict(X_test)
    
    # Undo scaling to compare predictions against original data
    original_df = load_original_df()
    unscaled = undo_scaling(predictions, X_test, scaler_object)
    unscaled_df = predict_df(unscaled, original_df)
      
    get_scores(unscaled_df, original_df, model_name)
    
    plot_results(unscaled_df, original_df, model_name)

# %% [markdown]
# # Linear Regression

# %%
run_model(train, test, LinearRegression(), 'LinearRegression')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: year 20060 is out of range
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\_libs\tslib.pyx:536, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\dateutil\parser\_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: year 20060 is out of range: 20060
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\_libs\tslib.pyx:547, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\dateutil\parser\_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\dateutil\parser\_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: year 20060 is out of range
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# c:\Users\MahmoodThe3rd\Desktop\python\sales_forecasting\notebooks\02_regression_modeling.ipynb Cell 18 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MahmoodThe3rd/Desktop/python/sales_forecasting/notebooks/02_regression_modeling.ipynb#ch0000017?line=0'>1</a> run_model(train, test, LinearRegression(), 'LinearRegression')
#
# c:\Users\MahmoodThe3rd\Desktop\python\sales_forecasting\notebooks\02_regression_modeling.ipynb Cell 18 in run_model(train_data, test_data, model, model_name)
#       <a href='vscode-notebook-cell:/c%3A/Users/MahmoodThe3rd/Desktop/python/sales_forecasting/notebooks/02_regression_modeling.ipynb#ch0000017?line=6'>7</a> predictions = mod.predict(X_test)
#       <a href='vscode-notebook-cell:/c%3A/Users/MahmoodThe3rd/Desktop/python/sales_forecasting/notebooks/02_regression_modeling.ipynb#ch0000017?line=8'>9</a> # Undo scaling to compare predictions against original data
# ---> <a href='vscode-notebook-cell:/c%3A/Users/MahmoodThe3rd/Desktop/python/sales_forecasting/notebooks/02_regression_modeling.ipynb#ch0000017?line=9'>10</a> original_df = load_original_df()
#      <a href='vscode-notebook-cell:/c%3A/Users/MahmoodThe3rd/Desktop/python/sales_forecasting/notebooks/02_regression_modeling.ipynb#ch0000017?line=10'>11</a> unscaled = undo_scaling(predictions, X_test, scaler_object)
#      <a href='vscode-notebook-cell:/c%3A/Users/MahmoodThe3rd/Desktop/python/sales_forecasting/notebooks/02_regression_modeling.ipynb#ch0000017?line=11'>12</a> unscaled_df = predict_df(unscaled, original_df)
#
# c:\Users\MahmoodThe3rd\Desktop\python\sales_forecasting\notebooks\02_regression_modeling.ipynb Cell 18 in load_original_df()
#       <a href='vscode-notebook-cell:/c%3A/Users/MahmoodThe3rd/Desktop/python/sales_forecasting/notebooks/02_regression_modeling.ipynb#ch0000017?line=3'>4</a> original_df.date = original_df.date.apply(lambda x: str(x)[:-3])
#       <a href='vscode-notebook-cell:/c%3A/Users/MahmoodThe3rd/Desktop/python/sales_forecasting/notebooks/02_regression_modeling.ipynb#ch0000017?line=4'>5</a> original_df = original_df.groupby('date')['sales'].sum().reset_index()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/MahmoodThe3rd/Desktop/python/sales_forecasting/notebooks/02_regression_modeling.ipynb#ch0000017?line=5'>6</a> original_df.date = pd.to_datetime(original_df.date)
#       <a href='vscode-notebook-cell:/c%3A/Users/MahmoodThe3rd/Desktop/python/sales_forecasting/notebooks/02_regression_modeling.ipynb#ch0000017?line=6'>7</a> return original_df
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\core\tools\datetimes.py:1051, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1049         result = arg.map(cache_array)
#    1050     else:
# -> 1051         values = convert_listlike(arg._values, format)
#    1052         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\core\tools\datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400 assert format is None or infer_datetime_format
#     401 utc = tz == "utc"
# --> 402 result, tz_parsed = objects_to_datetime64ns(
#     403     arg,
#     404     dayfirst=dayfirst,
#     405     yearfirst=yearfirst,
#     406     utc=utc,
#     407     errors=errors,
#     408     require_iso8601=require_iso8601,
#     409     allow_object=True,
#     410 )
#     412 if tz_parsed is not None:
#     413     # We can take a shortcut since the datetime64 numpy array
#     414     # is in UTC
#     415     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\core\arrays\datetimes.py:2242, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2240         return values.view("i8"), tz_parsed
#    2241     except (ValueError, TypeError):
# -> 2242         raise err
#    2244 if tz_parsed is not None:
#    2245     # We can take a shortcut since the datetime64 numpy array
#    2246     #  is in UTC
#    2247     # Return i8 values to denote unix timestamps
#    2248     return result.view("i8"), tz_parsed
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\core\arrays\datetimes.py:2224, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2222 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2223 try:
# -> 2224     result, tz_parsed = tslib.array_to_datetime(
#    2225         data.ravel("K"),
#    2226         errors=errors,
#    2227         utc=utc,
#    2228         dayfirst=dayfirst,
#    2229         yearfirst=yearfirst,
#    2230         require_iso8601=require_iso8601,
#    2231         allow_mixed=allow_mixed,
#    2232     )
#    2233     result = result.reshape(data.shape, order=order)
#    2234 except ValueError as err:
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\_libs\tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\_libs\tslib.pyx:613, in pandas._libs.tslib.array_to_datetime()
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\_libs\tslib.pyx:751, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\_libs\tslib.pyx:742, in pandas._libs.tslib._array_to_datetime_object()
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\pandas\_libs\tslibs\parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\dateutil\parser\_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\dateutil\parser\_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: year 20060 is out of range: 20060

# %% [markdown]
# # Random Forest Regressor

# %%
run_model(train, test, RandomForestRegressor(n_estimators=100, max_depth=20), 
          'RandomForest')
# Out:
# RMSE: 116732.84905144166
# MAE: 95987.5
# R2 Score: 0.5191793143716273
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # XGBoost

# %%
run_model(train, test, XGBRegressor( n_estimators=100, 
                                    learning_rate=0.2, 
                                    objective='reg:squarederror'), 'XGBoost')
# Out:
# RMSE: 116692.53780448003
# MAE: 95951.25
# R2 Score: 0.5195113397593893
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # LSTM

# %%
def lstm_model(train_data, test_data):
    
    X_train, y_train, X_test, y_test, scaler_object = scale_data(train_data, test_data)
    
    X_train = X_train.reshape(X_train.shape[0], 1, X_train.shape[1])
    X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])
   
    model = Sequential()
    model.add(LSTM(4, batch_input_shape=(1, X_train.shape[1], X_train.shape[2]), 
                   stateful=True))
    model.add(Dense(1))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    model.fit(X_train, y_train, epochs=200, batch_size=1, verbose=1, 
              shuffle=False)
    predictions = model.predict(X_test,batch_size=1)
    
    original_df = load_original_df()
    unscaled = undo_scaling(predictions, X_test, scaler_object, lstm=True)
    unscaled_df = predict_df(unscaled, original_df)
    
    get_scores(unscaled_df, original_df, 'LSTM')
    
    plot_results(unscaled_df, original_df, 'LSTM')

# %%
lstm_model(train, test)
# Out:
# Epoch 1/200
# 66/66 [==============================] - 2s 2ms/step - loss: 0.1198
# Epoch 2/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1147
# Epoch 3/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1133
# Epoch 4/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1122
# Epoch 5/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1111
# Epoch 6/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1101
# Epoch 7/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1091
# Epoch 8/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1080
# Epoch 9/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1069
# Epoch 10/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1057
# Epoch 11/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1043
# Epoch 12/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1029
# Epoch 13/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.1014
# Epoch 14/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0997
# Epoch 15/200
# 66/66 [==============================] - 0s 3ms/step - loss: 0.0980
# Epoch 16/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0962
# Epoch 17/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0944
# Epoch 18/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0926
# Epoch 19/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0908
# Epoch 20/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0892
# Epoch 21/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0876
# Epoch 22/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0861
# Epoch 23/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0847
# Epoch 24/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0833
# Epoch 25/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0821
# Epoch 26/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0808
# Epoch 27/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0797
# Epoch 28/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0786
# Epoch 29/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0775
# Epoch 30/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0765
# Epoch 31/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0754
# Epoch 32/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0744
# Epoch 33/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0735
# Epoch 34/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0725
# Epoch 35/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0716
# Epoch 36/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0707
# Epoch 37/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0698
# Epoch 38/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0689
# Epoch 39/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0681
# Epoch 40/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0672
# Epoch 41/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0664
# Epoch 42/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0656
# Epoch 43/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0648
# Epoch 44/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0640
# Epoch 45/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0632
# Epoch 46/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0624
# Epoch 47/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0617
# Epoch 48/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0609
# Epoch 49/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0602
# Epoch 50/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0595
# Epoch 51/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0587
# Epoch 52/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0580
# Epoch 53/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0573
# Epoch 54/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0566
# Epoch 55/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0559
# Epoch 56/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0552
# Epoch 57/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0545
# Epoch 58/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0538
# Epoch 59/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0531
# Epoch 60/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0525
# Epoch 61/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0518
# Epoch 62/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0511
# Epoch 63/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0505
# Epoch 64/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0499
# Epoch 65/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0492
# Epoch 66/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0486
# Epoch 67/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0480
# Epoch 68/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0474
# Epoch 69/200
# 66/66 [==============================] - 0s 3ms/step - loss: 0.0468
# Epoch 70/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0462
# Epoch 71/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0456
# Epoch 72/200
# 66/66 [==============================] - 0s 4ms/step - loss: 0.0450
# Epoch 73/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0444
# Epoch 74/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0439
# Epoch 75/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0433
# Epoch 76/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0428
# Epoch 77/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0422
# Epoch 78/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0417
# Epoch 79/200
# 66/66 [==============================] - 0s 3ms/step - loss: 0.0412
# Epoch 80/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0407
# Epoch 81/200
# 66/66 [==============================] - 0s 3ms/step - loss: 0.0402
# Epoch 82/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0397
# Epoch 83/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0393
# Epoch 84/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0388
# Epoch 85/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0383
# Epoch 86/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0379
# Epoch 87/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0375
# Epoch 88/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0370
# Epoch 89/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0366
# Epoch 90/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0362
# Epoch 91/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0358
# Epoch 92/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0354
# Epoch 93/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0351
# Epoch 94/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0347
# Epoch 95/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0344
# Epoch 96/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0340
# Epoch 97/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0337
# Epoch 98/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0334
# Epoch 99/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0330
# Epoch 100/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0327
# Epoch 101/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0324
# Epoch 102/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0322
# Epoch 103/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0319
# Epoch 104/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0316
# Epoch 105/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0313
# Epoch 106/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0311
# Epoch 107/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0308
# Epoch 108/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0306
# Epoch 109/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0304
# Epoch 110/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0301
# Epoch 111/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0299
# Epoch 112/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0297
# Epoch 113/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0295
# Epoch 114/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0292
# Epoch 115/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0290
# Epoch 116/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0288
# Epoch 117/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0286
# Epoch 118/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0284
# Epoch 119/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0282
# Epoch 120/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0280
# Epoch 121/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0278
# Epoch 122/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0276
# Epoch 123/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0275
# Epoch 124/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0273
# Epoch 125/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0271
# Epoch 126/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0269
# Epoch 127/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0267
# Epoch 128/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0265
# Epoch 129/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0264
# Epoch 130/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0262
# Epoch 131/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0260
# Epoch 132/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0258
# Epoch 133/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0257
# Epoch 134/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0255
# Epoch 135/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0253
# Epoch 136/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0251
# Epoch 137/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0250
# Epoch 138/200
# 66/66 [==============================] - 0s 3ms/step - loss: 0.0248
# Epoch 139/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0246
# Epoch 140/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0245
# Epoch 141/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0243
# Epoch 142/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0241
# Epoch 143/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0240
# Epoch 144/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0238
# Epoch 145/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0237
# Epoch 146/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0235
# Epoch 147/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0233
# Epoch 148/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0232
# Epoch 149/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0230
# Epoch 150/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0229
# Epoch 151/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0227
# Epoch 152/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0225
# Epoch 153/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0224
# Epoch 154/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0222
# Epoch 155/200
# 66/66 [==============================] - 0s 4ms/step - loss: 0.0221
# Epoch 156/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0219
# Epoch 157/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0218
# Epoch 158/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0216
# Epoch 159/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0215
# Epoch 160/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0213
# Epoch 161/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0212
# Epoch 162/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0211
# Epoch 163/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0209
# Epoch 164/200
# 66/66 [==============================] - 0s 3ms/step - loss: 0.0208
# Epoch 165/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0206
# Epoch 166/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0205
# Epoch 167/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0204
# Epoch 168/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0202
# Epoch 169/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0201
# Epoch 170/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0200
# Epoch 171/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0198
# Epoch 172/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0197
# Epoch 173/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0196
# Epoch 174/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0194
# Epoch 175/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0193
# Epoch 176/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0192
# Epoch 177/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0191
# Epoch 178/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0189
# Epoch 179/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0188
# Epoch 180/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0187
# Epoch 181/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0186
# Epoch 182/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0184
# Epoch 183/200
# 66/66 [==============================] - 0s 3ms/step - loss: 0.0183
# Epoch 184/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0182
# Epoch 185/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0181
# Epoch 186/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0180
# Epoch 187/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0179
# Epoch 188/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0178
# Epoch 189/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 190/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0175
# Epoch 191/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0174
# Epoch 192/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0173
# Epoch 193/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0172
# Epoch 194/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0171
# Epoch 195/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 196/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0169
# Epoch 197/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0168
# Epoch 198/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0167
# Epoch 199/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0166
# Epoch 200/200
# 66/66 [==============================] - 0s 2ms/step - loss: 0.0165
# 12/12 [==============================] - 0s 1ms/step
# RMSE: 116818.61638205044
# MAE: 96064.75
# R2 Score: 0.5184725063610861
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\Users\MahmoodThe3rd\anaconda3\envs\py39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pickle.dump(model_scores, open( "model_scores.p", "wb" ) )
